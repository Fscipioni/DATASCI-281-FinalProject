# %%
import os
import pandas as pd
import requests
from PIL import Image

# %%
df = pd.read_csv('movies_dataset_final.csv')
df.dropna(inplace=True, axis=0)
df = df.reset_index(drop=True)
df.drop('Unnamed: 0', inplace=True, axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27454 entries, 0 to 27453
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tconst    27454 non-null  object
#  1   title     27454 non-null  object
#  2   year      27454 non-null  object
#  3   genre     27454 non-null  object
#  4   director  27454 non-null  object
#  5   actors    27454 non-null  object
#  6   plot      27454 non-null  object
#  7   country   27454 non-null  object
#  8   awards    27454 non-null  object
#  9   poster    27454 non-null  object
#  10  rating    27454 non-null  float64
#  11  votes     27454 non-null  int64
#  12  type      27454 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 2.7+ MB

# %%
df.head(10)
# Out:
#        tconst                        title  year                    genre  \
# 0   tt3608918                    Azzurrina  2023                   Horror
# 1  tt15908496                  Dear Jackie  2021              Documentary
# 2  tt28378602    Zena s gumenim rukavicama  2023                    Drama
# 3  tt27129223  Fast Shark II: Faster Shark  2023           Comedy, Sci-Fi
# 4  tt15173938               Shooting Guard  2022                 Thriller
# 5  tt21271136             Selling Superman  2024              Documentary
# 6  tt10508276                Santo Domingo  2020     Documentary, History
# 7  tt18938184    Phantom: The Musical Live  2021  Drama, Musical, Romance
# 8  tt26546131             Close the Divide  2023              Documentary
# 9  tt11596916                 Muhammed Ali  2019              Documentary
#
#                              director  \
# 0                   Giacomo Franciosa
# 1                         Henri Pardo
# ...

# %%
posters = df['poster'].to_list()

# %%
# url = posters[0]
# data = requests.get(url).content 

# f = open('Data/' + df['tconst'][0] + '.jpg','wb') 
  
# # Storing the image data inside the data variable to the file 
# f.write(data) 
# f.close() 
  
# # # Opening the saved image and displaying it 
# # img = Image.open('Data/img.jpg') 
# # img.show()

# %%
# for i, url in enumerate(posters):
#     data = requests.get(url).content 
#     # print(df['tconst'][i])
#     # print(i)
#     f = open('Data/' + df['tconst'][i] + '.jpg','wb') 
#     f.write(data) 
#     f.close()

# %%
count = df[df['genre'].str.contains('Documentary', case=False, na=False)].shape[0]

print(f"Number of rows containing 'Documentary': {count}")
# Out:
# Number of rows containing 'Documentary': 10757

# %%
count = df[df['country'].str.contains('United States', case=False, na=False)].shape[0]

# %%
count
# Out:
# 9135

# %%
df[df['genre'] == 'Horror'].head(20)
# Out:
#           tconst                                            title  year  \
# 0      tt3608918                                        Azzurrina  2023
# 334    tt4644510                            P=wp L'Energie Sombre  2015
# 381   tt26424600                                     Inner Demons  2023
# 382    tt9248472          Blood Alley - Chillicothe Makes a Movie  2018
# 495    tt3789538                                        Bhaangarh  2014
# 672   tt33058876                         Hell Squad 2: Fresh Meat  2024
# 705    tt5097012                                               21  2016
# 831   tt12959292                                    Nexus of Evil  2020
# 885    tt6642212                The Ministry of Stories Anthology  2017
# 988   tt32793025  Halloween: The Hunt of Michael Myers (Fan Film)  2024
# 1088   tt6134982                Dark Ditties Presents 'The Offer'  2017
# 1123   tt8763994                                            Thr33  2016
# ...
